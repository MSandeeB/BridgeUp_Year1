# %% [markdown]
# # Let's map some earthquakes!
#
# Use this notebook to complete your final project for unit 1. You'll use a "for loop" and conditionals to select the right earthquakes to plot on your map and discover something about the seismic activity in your region.

# %% [markdown]
# ## Data Setup
# In this section we'll open up our data file and turn it into a list of lists that we can work with using "for loops".

# %% [markdown]
# We'll be making a graph, so import the matplotlib.pyplot library with the alias plt:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Next, we will open the data file using the open() function and then skip the first row using the .readline() method:

# %%
all_quakes = open("quakes_project.txt")
all_quakes.readline()

# The \t in between each column name lets you know that this text file is separated by tabs
# Out:
# 'YEAR\tFOCAL_DEPTH\tEQ_PRIMARY\tCOUNTRY\tSTATE\tLOCATION_NAME\tLATITUDE\tLONGITUDE\tREGION_CODE\tDEATHS\tDAMAGE_MILLIONS_DOLLARS\tHOUSES_DESTROYED\tHOUSES_DESTROYED_DESCRIPTION\tHOUSES_DAMAGED\n'

# %% [markdown]
# Currently our file is one long string. Let's make each line of the data file a list and put all of those lists into one big list called quakes_list.

# %%
quakes_list = []
for i in all_quakes:
    quakes_list.append(i.split('\t')) # The .split() method separates the items in each line

# %%
print(quakes_list[0])
# Out:
# ['1800', '', '', 'MEXICO', '', '"MEXICO:  MEXICO CITY,OAXACA"', '19.2', '-99.1', '150', '', '', '', '', '\n']

# %% [markdown]
# Print out the length of quakes_list to see how many earthquakes are in our data file:

# %%
print(len(quakes_list))
# Out:
# 4596

# %% [markdown]
# ## Selecting your data
# In this section you'll decide which data you need for your project. You'll use "for loops" and conditionals to select the right data.

# %% [markdown]
# You will need latitudes and longitudes for your scatter plot, so create two empty lists to hold those values:

# %%
lat = []
lon = []

# %% [markdown]
# Next, decide as a group what range of years you want to look at (between 1800 and 2018). You should base your decision on the research you did on the seismic activity in your region.

# %% [markdown]
# You'll also need to know the "region code" for your region:
# - Africa: 10
# - Central America: 100
# - Central and South Pacific: 170
# - North America: 150
# - South America: 160

# %% [markdown]
# Create a "for loop" that loops through the lines in quakes_list and appends the latitute and longitude to the lists you created above **if** the earthquake for that row occurred in your region and during your year range.
#
# Hints:
# - You can nest an if statement inside another if statement
# - You can compare a value to two other values like this: 5 < x < 10

# %%
lat = []
lon = []
for i in quakes_list:
    if int(i[0])>1990 and int(i[8]) == 170:
        lat.append(float(i[6]))
        lon.append(float(i[7]))
        
print(lat)
print(lon)
# Out:
# [5.865, 15.119, 1.196, -8.099, -9.094, -9.929, -40.25, -7.138, 7.191, -11.122, -14.385, -28.886, 12.982, -5.889, -18.039, -4.967, -10.477, -10.362, -10.777, -10.341, 13.525, 1.015, -1.258, -42.963, -15.199, -2.045, -8.452, 12.059, 12.047, -4.183, -5.799, -23.008, -37.759, 0.729, -0.891, -6.518, -22.101, -3.776, 1.241, 13.986, -12.584, -8.194, -2.071, -2.943, -6.845, 15.766, -16.423, -4.612, -4.721, -6.675, 20.253, -1.105, -5.496, -4.001, -5.233, -4.102, 6.898, 12.686, -21.696, 2.824, -1.196, 6.033, -1.68, -1.757, -3.212, -3.26, 13.088, 14.101, -14.49, -17.6, -23.884, -6.983, -8.807, -8.137, -8.294, 12.171, 12.168, 12.025, 1.142, 2.354, -10.491, -45.104, -22.107, -43.34, 3.316, -1.559, -1.549, -0.466, -8.669, -8.31, -9.362, 9.926, -8.152, -3.12, -4.003, -3.609, -3.615, -49.312, -46.676, -38.0, 2.085, -1.198, -1.174, -9.948, -4.539, -41.223, -20.187, -16.592, 3.462, 0.626, -5.575, -9.254, -8.251, -3.728, -3.595, -5.473, 2.52, -25.996, -0.493, -5.968, -7.783, -8.277, 9.721, 6.614, 1.065, -1.065, 2.872, -8.466, -49.418, -11.61, -44.785, -15.595, -20.617, -39.011, 2.768, 1.011, 1.271, 12.897, -0.795, -20.071, -19.941, -39.715, -23.046, -15.489, -2.515, -7.782, -9.138, -8.207, 6.513, 3.884, -0.414, -0.691, -38.28, -12.517, -13.006, -45.762, -17.757, -17.026, -30.794, 6.486, -2.174, 12.484, 16.591, -8.799, -8.743, -9.019, -19.702, -17.541, -43.522, -43.57, -43.55, -43.598, -40.433, -29.539, -28.993, -4.586, 7.904, 9.457, -18.365, -18.311, -19.157, -43.583, -43.564, -43.49, -41.364, -1.315, 9.999, 12.354, 10.037, 10.811, -9.694, -17.827, -18.972, 9.88, 7.275, -10.799, -10.928, -41.731, -41.704, -29.977, 6.864, 1.893, -6.755, -6.586, -11.463, -11.27, -40.66, 5.987, -8.338, 10.169, -0.59, -2.629, -5.462, -4.729, -9.307, -10.401, -16.431, 1.279, -3.873, 18.543, -4.509, -10.73, -10.665, -16.043, -42.757, -22.477, -37.401, -1.289, 13.725, 11.114, 11.014, 7.629, 5.516, 9.911, 9.831, -3.745, 2.382, -6.214, -21.334, -21.63, -21.66, -19.326, -18.178, -5.841, -6.182, -6.294, -6.307, -6.068, -22.066, -18.494]
# [116.746, 120.355, 122.787, 124.681, 158.442, 159.139, 175.053, 109.067, 126.762, 165.239, -178.252, -176.819, 144.801, 146.02, -178.413, 104.302, 112.835, 112.892, 113.366, 113.369, 121.067, 127.733, 127.98, 171.658, -173.529, 101.436, 125.049, 125.58, 125.92, 135.109, 154.178, 169.9, 178.752, 119.931, 136.952, 154.999, -176.772, 119.727, 122.536, 144.901, 166.676, 112.413, 124.891, 142.582, 105.555, 119.74, 168.214, 101.905, 102.087, 106.845, 122.043, 123.573, 151.781, 152.327, 153.102, 123.907, 126.579, 144.98, -179.513, 96.085, 121.333, 124.249, 134.234, 134.297, 142.427, 142.94, 144.619, 146.199, 167.827, 167.856, 178.495, 108.468, 118.524, 120.524, 120.743, 123.921, 124.079, 125.416, 128.152, 128.855, 160.77, 167.144, 169.35, 173.04, 95.854, 100.488, 100.54, 100.655, 114.65, 115.788, 122.839, 124.038, 124.868, 127.4, 135.023, 135.404, 135.538, 161.345, 164.721, 176.51, 97.108, 119.933, 119.963, 124.48, 153.474, 175.21, -174.123, -172.033, 97.224, 99.859, 105.395, 107.411, 118.777, 119.233, 127.214, 128.131, 128.283, -177.514, 100.498, 107.655, 114.338, 118.339, 124.647, 126.24, 126.282, 127.343, 127.464, 157.043, 163.954, 165.762, 167.583, 167.68, 169.357, 178.291, 95.964, 97.442, 122.091, 124.319, 134.012, 168.892, 168.953, 176.851, -174.659, -172.095, 101.501, 107.297, 115.593, 118.631, 124.715, 126.397, 132.885, 133.305, 145.25, 166.382, 166.51, 166.562, 167.949, 168.329, 121.406, 123.467, 136.543, 141.476, 145.682, 157.346, 157.477, 157.551, 167.947, 168.069, 171.83, 172.388, 172.647, 172.69, 176.818, -176.34, -176.238, 122.771, 125.185, 125.935, 168.143, 168.218, 168.311, 172.68, 172.743, 172.8, 174.315, 120.096, 123.206, 123.7, 125.633, 126.638, 159.727, 167.133, 168.741, 124.117, 124.898, 165.114, 166.018, 174.027, 174.337, -177.725, 125.233, 126.522, 155.024, 155.049, 162.051, 162.148, 175.814, 116.541, 124.875, 125.891, 131.27, 138.528, 151.875, 152.562, 158.403, 165.141, 168.148, 126.371, 127.229, 145.507, 153.45, 161.107, 161.335, 167.379, 173.077, 173.117, 179.055, 120.453, 120.929, 124.633, 124.736, 124.874, 125.093, 125.461, 125.496, 127.752, 128.144, 155.122, 168.683, 168.884, 169.203, 176.053, -178.111, 142.49, 142.492, 142.607, 142.62, 142.768, 170.05, 179.332]

# %% [markdown]
# Print out the length of your latitude and longitude lists. Does this result make sense?

# %%
print(len(lon))
print(len(lat))
# Out:
# 250
# 250

# %% [markdown]
# ## Making your graph
# Now that you've created lists with your x data (longitude) and y data (latitude) it's time to make a scatter plot!

# %% [markdown]
# Replace the coordinates in plt.xlim and plt.ylim functions below as follows:
# - Africa: x = (-25,50), y = (-40,45)
# - Central America: x = (-100,-70), y = (0,25)
# - Central and South Pacific: x = (80,180), y = (-70,30)
# - North America: x = (-180,-50), y = (0,90)
# - South America: x = (-120,-20), y = (-60,20)

# %%
# This function clears any leftover plots
plt.clf()

# This code adds an image behind your plot
image = plt.imread("earth.jpg")
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])

# This code crops the image to show only your region. 
# IMPORTANT: Replace the coordinates in plt.xlim and plt.ylim functions
# To match your region using the key above
plt.xlim(80,180)
plt.ylim(-70,30)




plt.scatter(lon, lat, label = "Earthquake", color = "sandybrown")
plt.title("Central and South Pacific Earthquake")
plt.xlabel("Longtitude")
plt.ylabel("Latitude")
plt.legend()
plt.savefig("quakes_graph.png", dpi = 1000)
plt.show()

# Create a scatter plot using plt.scatter(). 
# You can change the size, shape, and color of your markers! 
# Try adding s = #, marker = "symbol", and c = "color"

# Don't forget plt.show()!

# %% [markdown]
# ### Modify the points on your graph!
# You can find the complete list of possible markers here: https://matplotlib.org/api/markers_api.html
#
# and the possible colors here: https://i.stack.imgur.com/lFZum.png

# %% [markdown]
# ### Download your graph
#
# When you're happy with your graph, you can download it to your computer using the plt.savefig() function. This function takes two arguments: whatever you'd like to name the file in a string (ex: "quakes_graph.png") and dpi=1000. The file will be downloaded to the same folder as the Jupyter Notebook file.
#
# **Note: You will need to comment out plt.show() and rerun your graphing code before running plt.savefig().**
#
# plt.show() outputs the graph and prevents you from downloading it to your computer.

# %%
# Example: plt.savefig("quakes_graph.png", dpi = 1000)

# %% [markdown]
# ## Mapping tectonic plate boundaries
# Copy and paste all your graphing code in the cell below. Then change replace **image = plt.imread("earth.jpg")** with **image = plt.imread("plates.png")**
#
# Run your code and examine the results! Do you see what you expect?

# %%
# This function clears any leftover plots
plt.clf()

# This code adds an image behind your plot
image = plt.imread("plates.png")
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])

# This code crops the image to show only your region. 
# IMPORTANT: Replace the coordinates in plt.xlim and plt.ylim functions
# To match your region using the key above
plt.xlim(80,180)
plt.ylim(-70,30)




plt.scatter(lon, lat, label = "Earthquake", color = "sandybrown")
plt.title("Central and South Pacific Earthquake")
plt.xlabel("Longtitude")
plt.ylabel("Latitude")
plt.legend()
plt.savefig("platesquakes_graph.png", dpi = 1000)
plt.show()

# Create a scatter plot using plt.scatter(). 
# You can change the size, shape, and color of your markers! 
# Try adding s = #, marker = "symbol", and c = "color"

# Don't forget plt.show()!
